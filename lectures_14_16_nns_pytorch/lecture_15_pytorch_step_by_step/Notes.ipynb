# %% [markdown]
# # In the lecture we will use the following sources:

# %% [markdown]
# https://www.youtube.com/watch?v=aircAruvnKk

# %% [markdown]
# https://docs.pytorch.org/tutorials/

# %% [markdown]
# https://www.kaggle.com/code/pkdarabi/brain-tumor-detection-by-cnn-pytorch

# %% [markdown]
# https://www.kaggle.com/code/annastasy/pet-image-recognition-with-pytorch/notebook

# %% [markdown]
# https://docs.pytorch.org/vision/stable/models/resnet

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2025/01/yolov11-model-building/
