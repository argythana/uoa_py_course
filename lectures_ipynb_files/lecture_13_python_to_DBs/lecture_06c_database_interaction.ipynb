# %% [markdown]
# # Lecture 13: Python interaction with databases. Advanced optional material.
#
# ### Work in Progress, thanks to class of 2024 for always asking for more.
# Generated by asking the right prompts to an AI, curated, corrected and filtered by you know who.
#
# **Not yet uploaded on eclass.**

# %% [markdown]
# # tools to interact with Databases
#
# python for sql
#
# https://duckdb.org/2023/02/24/jupysql.html

# %% [markdown]
# https://github.com/ploomber/jupysql
