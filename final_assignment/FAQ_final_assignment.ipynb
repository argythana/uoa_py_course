# %% [markdown]
# <h1>Final assignment, Frequently Asked Questions</h1>
#
# **Thank you for asking, this helps me, you, and everyone else!**
#
# ## Assignment Objective
#
# Your work for the assignment and its outcome should satisfy, first and foremost, you, not me. Follow you passion and meet the 'Technical Requirements` of the assignment.
#
# ## When to begin?
#
# Yesterday!
# Start searching for datasets after thinking about what is interesting for you and after reading:
#
# * the assignment instructions,
# * guidelines for selecting datasets,
# * FAQ about the assignment.
#
# You may start writing code after the lecture on the `pandas` library. If you are already familiar with Python, you should have started already.
#
# ## Use of AI assistants and coding copilots
#
# This is mandatory for the course and the assignment. Think of it as a multiplier. Will multiply your skills, but also might multiply your inefficiencies. Use properly and mind the caveats.
#
# ---
#
# ## Dataset Selection
#
# - Searching for and selecting appropriate datasets is part of the assignment.
# - No approval is needed, no approval will be given.
# - Read carefully the dataset selection guidelines.
# - Possible sources:
#   - UCI Machine Learning Repository.
#   - Kaggle Datasets / Competitions.
#   - Your own dataset (if applicable)
#   - !Todo: Add more sources
# - Dataset selection deadline: **May 31**. But, the sooner the better.
#
# ## Deadline
#
# Submit on e-class,
# - On Sunday, before the first exam date, 23:45. Every year, exams start the last week of June.
# - No deadline extension will be be given, except for serious personal reasons.
#
# ---
#
# The total grade for the course is calculating by adding your final assignment grade, plus extra points for submitting practice exercises after each lecture.
#
# **1) Q: May I select a dataset from Kaggle with a "Usability Rating" lower than 8? I have found a dataset with a rating of 2.4.**
#
# A: Yes, the decision is yours. Selecting a suitable dataset is part of the assignment. But, it is not recommended because a low usability rating means it might be more difficult to gain meaningful insights and apply Machine Learning Algorithms on the data.
# You are encouranged to look at other notebook submissions on Kaggle and see for yourself what others have already done with this dataset.
#
# **2) Q: Another student has selected a similar subject. Is this Ok?**
#
# A: Yes, you may even select the exact same subject, as long as you use different datasets.
#
# **3) Q: Besides the list of datasets that we should not use, are there any other datasets that we should not use?**
#
# A: You may not use any dataset that has been used as a tutorial example. The list in the guidelines may not be updated, or extensive.
#
# **4) Q: Every year some students select datasets without reading the guidelines carefully. Some even selectdatasets that are explicitly mentioned in the "Don't select" sections. What can I do as an educator?**
#
# A: Write a question, include it in the FAQ and write the reply too. This will highlight the need to read the instructions carefully once more, and at the same time is like making a small joke about it. Jokes draw attention and are slightly more memorable, even bad jokes like this one. By the way, the **Don't Repeat Yourself (DRY)** principle applies in programming. In education, there should be a principle called: **Repeat Everything At Least Thrice (REALT)** and more if you have to.
#
# ## Final Notes
# - I am at your disposal for any assistance or help, even after this course ends.
# - Thank you for your participation, your feedback makes this course better for your peers and future cohorts!
#
# Ps. FAQ will be updated, thanks to you!
