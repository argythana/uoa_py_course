# %% [markdown]
# <mark>Todo:</mark>: Create extra notebook for user-defined modules and the `if __name__ == "__main__"` statement.
#
#
#
# # Lecture 6b: User-defined functions.
#
# > Purpose: decomposition, abstraction, reusability.
# > Modularity, modular development.
# > Syntax: `def`, :, indented blocks, `docstrings`, `return` statement.
# > Parameters
# > Arguments
#
# When something is repeated in the code => define a function. Don't Repeat Yourself (DRY).
# When a task needs to be repeated => define a function. DRY.
#
# Suggested (suggested means absolutely necessary) videos to watch after class:
#
# * a. When and how to write functions: [The Mental Game of Python - Raymond Hettinger 2019](https://www.youtube.com/watch?v=UANN2Eu6ZnM&t=298s)
# My favourite quote:
# > "I Make new words to make computers easier to use."
#
# Make sure you understand the stragegies presented right from the start (from 2:50 onwards).
# For `inheritance`, see from 36:00 to 46:00.
# Quote: "Build classes independently and let inheritance discover itself. Should not plan too many steps in advance: "Combinatory explosion"
#
# Watch this part at least twice to think when to define functions: from 47:45 to 01:01:05.
# Quote:
# > "Repeat tasks manually until patterns emerge. Then, move to a function.
# > If `def` is the first word, you make your life worse."
#
# * b. Simple tips for beginners to properly define functions. [The ultimate guide to writing functions.](https://www.youtube.com/watch?v=yatgY4NpZXE)

# %% [markdown]
# ### Basic syntax of  definition and calling
# 1. Define a function:
#     `def function_name(parameters):`
#
#     docstrings = documentation string = output of help(function_name)
#
#     Body as indented block: always 4 blank spaces.
#     Functionc Body = state what to do.
#
#     Return function output: a return statement. Return value to the caller.
#
# 2. Call a function:
# `function_name(arguments)`
#
# * `Parameters` = "names" in definition.
# * `Arguments` = "values" in call.
#
# 3. Assign the result of the function to a variable:
# `value = function_name(arguments)`
#
#
# ### Tips to get you started:
# First write the code line by line, as a script, when it works, define is as a function.
#
# Use debugging statements e.g. print(), within the function, to test and inspect the intermediate results.

# %% [markdown]
# ## 1. Simple function without parameters

# %%
# a very useless function.
def teach_user_defined_docstrings():
    """
    This is a useless function. Its purpose is to waste your time.
    """
    print("The most useless function ever, was written by Thanasis Argyriou.")

    teacher_character = "boring and not funny"

    return teacher_character

# %%
print(teach_user_defined_docstrings.__doc__)
# Out:
#     This is a useless function. Its purpose is to waste your time.

# %%
help(teach_user_defined_docstrings())
# Out:
# The most useless function ever, was written by Thanasis Argyriou.
# No Python documentation found for 'boring and not funny'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %% [markdown]
# ## 2. Simple function with sinlge parameter without default value

# %%
def simple_msg_without_default_value(message):
    message = message.upper()

    # print(message)
    return message

# %%
simple_msg_without_default_value("HELLLOOsfdgsfgsdfsgTTTTOOO")
# Out:
# 'HELLLOOSFDGSFGSDFSGTTTTOOO'

# %%
modified_msg = simple_msg_without_default_value("HELLLOOsfdgsfgsdfsgTTTTOOO")

# %%
modified_msg
# Out:
# 'HELLLOOSFDGSFGSDFSGTTTTOOO'

# %% [markdown]
# ## 3. Simple function with single parameter with default value

# %%
# Recommended style: no blank space between argument and value in definition.
def simple_msg(message="Python is great."):
    """Print the message.
    default value=Python is great."""
    print(message)

# %%
# call with default value
simple_msg()
# Out:
# Python is great.

# %%
# Call using a new value, not the default value.
simple_msg(message='Python is boring!')
# Out:
# Python is boring!

# %%
# function doc
help(simple_msg)
# Out:
# Help on function simple_msg in module __main__:
#
# simple_msg(message='Python is great.')
#     Print the message.
#     default value=Python is great.

# %% [markdown]
# ## 4. Simple function with multiple parameters and one default value

# %%
# 3 args, 2 non-default, 1 default value
# assign value to positional args before keyword (else => SyntaxError)
# output  order not the same thing as input order!
def message_from_to(sender, receiver, message='Please study'):
    """
    Print the message from the sender to the receiver.
    """
    print(sender, message, receiver)  # Very Bad order, still works.

# %%
message_from_to('Thanasis:', 'dear Students,')
# Out:
# Thanasis: Please study dear Students,

# %%
message_from_to('Thanasis', 'students', 'kindly asks you to study, dear')
# Out:
# Thanasis kindly asks you to study, dear students

# %%
# Both work syntatically. Which is "wrong", why ?
message_from_to('Students:', 'Thanasis', 'No way, this is so boring!')
# Out:
# Students: No way, this is so boring! Thanasis

# %%
message_from_to('Students:', 'No way this is so boring!', 'Thanasis')
# Out:
# Students: Thanasis No way this is so boring!

# %% [markdown]
# ## 5 . Simple function with multiple parameters, one default value and conditions

# %%
# 3 args, 2 non-default, 1 default value
# assign value to positional args before keyword (else => SyntaxError)
# output  order not the same thing as input order!
def message_from_to(sender, receiver, message='Please study'):
    """
    Print the message from the sender to the receiver.
    Deliver different messages to different receivers.
    """
    if receiver == 'students':
        # message = message + " ,please, please, please."
        message = "Do what you really want,"

    elif receiver == 'Manos':
        message = "Please ask more questions,"

    print(sender, message, receiver)  # Very Bad order, still works.

# %%
message_from_to('Thanasis:', 'Manos')
# Out:
# Thanasis: Please ask more questions, Manos

# %%
message_from_to('Thanasis:', 'students')
# Out:
# Thanasis: Do what you really want! students

# %% [markdown]
# ## 6. Simple function to calculate order cost
# This function works but is defined in a bad way.

# %%
def calc_order(q, items, p):
    total = q * p
    print(f'{q} {items}, cost {total} \n')  # Match definition order.

# %%
# Order of arguments value assignemnt matches definition,
calc_order(3, 'books', 10)
# Out:
# 3 books, cost 30

# %%
# Order of values passed in function, call in this case DOES NOT match definition, flexible order.
calc_order(items='books', p=10, q=3)
# Out:
# 3 books, cost 30

# %% [markdown]
# #### How this function could be defined for better readability
# **Recommendation:** Provide general purpose, descriptive and intuitive names for functions and variables.

# %%
def calculate_order_cost(quantity, item_name):  # no object type specified
    """
    Calculate the cost from an order of N itmes.
    Prices are determined from a menu list, not from the user.
    Arguments:
        quantity: number of items
        item_name: name of the item
    Returns:
        total_cost: total cost of the order,
    """
    prices = {'books': 10, 'pens': 2, 'pencils': 1}  # In practice this is from a database, not inside the function.

    total_cost = quantity * prices[item_name]
    print(f'{quantity} {item_name} cost {total_cost} euros.\n')

    return total_cost

# %%
calculate_order_cost(5, 'books')
# Out:
# 5 books cost 50 euros.
# 50

# %% [markdown]
# ## 7. Modular development of functions.
#
# Functions are used to decompose a problem into smaller parts.
# Each function should do one thing only and do it well.
# When facing a complex problem, we split it in smaller tasks, we define functions for each small task.
# We can call these smaller function from another function.
#
# Name space, global and local scope in variables [Extra, advanced reading](https://docs.python.org/3/tutorial/classes.html#python-scopes-and-namespaces).
#
# Local scope of a variable: is available, only within the function or the code block.
# Global scope of variable: is available in the module.

# %%
# no reference to math module when sqrt() is called.
from math import sqrt

# This way to use sqrt you need: math.sqrt()
# import math


def myhypot(x, y):
    '''CALCULATE hypotenuse. Assign values for x, y.'''
    # no reference to math module when using sqrt()
    hyp = sqrt(x*x + y*y)  # hyp = local variable
    return hyp  # The result only is returned by the function back to the called. Not the name value pair.
# Need to pass exactly two arguments inside
myhypot(6, 8)
# define a second function that uses another function:

def hypot_calculator():
    '''Ask for triangle sides and print hypotenuse. Input should be numbers.'''
    a = float(input("Insert side a: "))
    b = float(input("Insert side b: "))
    H = myhypot(a,b)  # call function hyp()
    print ("Hypotenuse = ", H)
#
hypot_calculator()  # 3, 4
# TypeError: hypot_calculator() takes 0 positional arguments but 2 were given
hypot_calculator(3, 4)
#  TypeError: unexpected keyword argument.
hypot_calculator(x=3, y=4)

# %% [markdown]
# ## 8. Functions with arbitrary number of args *

# %%
def multiply(*my_arguments, end="hi!"):
    s = 1  # neutral factor in multiplication.
    for number in my_arguments:
        s *= number  # this syntax means  s = s*n
        print(s)
    print(end)
    #print(s) 

multiply(1, 2, 3, 4, end="This is the end of the function")
# Out:
# 1
# 2
# 6
# 24
# This is the end of the function

# %%
# take your time to see why we get this result!
my_example_list = [1, 2, 3, 4, 5, 6]
multiply(my_example_list, 2, 3, 4, 5)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]
# hi!

# %%
my_example_string = "my_imagination_is_that_of_a_brick"

multiply(my_example_string)
# Out:
# my_imagination_is_that_of_a_brick
# hi!

# %%
def multiply_iterable_objects(*my_object):
    i = 1  # initiate a number to count.
    print(my_object)
    for iterable_object in my_object:
        for item in iterable_object:
            i = i + 1  # a simple counter.
            item = i * item  
            print(item)

# %%
my_example_string = "brick"

multiply_iterable_objects(my_example_string)
# Out:
# ('brick',)
# bb
# rrr
# iiii
# ccccc
# kkkkkk

# %%
my_example_list = [1, 2, 3, 4, 5, 6]

multiply_iterable_objects(my_example_list)
# Out:
# ([1, 2, 3, 4, 5, 6],)
# 2
# 6
# 12
# 20
# 30
# 42

# %%
# can you spot the mistake of the function above in this example?
my_example_string = "brick"
my_example_list = [1, 2, 3, 4, 5, 6]

multiply_iterable_objects(my_example_string, my_example_list)
# Out:
# ('brick', [1, 2, 3, 4, 5, 6])
# bb
# rrr
# iiii
# ccccc
# kkkkkk
# 7
# 16
# 27
# 40
# 55
# 72

# %%
# can you spot the problem here ?
def multiply_iterable_objects(*my_object):
    i = 1
    print(my_object)
    for iterable_object in my_object:
        i = i + 1
        for item in iterable_object:       
            item = i * item  
            print(item)

            
multiply_iterable_objects(my_example_string, my_example_list)
# Out:
# ('brick', [1, 2, 3, 4, 5, 6])
# bb
# rr
# ii
# cc
# kk
# 3
# 6
# 9
# 12
# 15
# 18

# %%
# this is a consistent definition, that performs the same process in any iterable input.
def multiply_iterable_objects(*my_object):  
    print(my_object)
    for iterable_object in my_object:
        i = 0  # initiate a number to count.
        for item in iterable_object:
            i = i + 1
            item = i * item  
            print(item)

multiply_iterable_objects(my_example_string, my_example_list)
# Out:
# ('brick', [1, 2, 3, 4, 5, 6])
# b
# rr
# iii
# cccc
# kkkkk
# 1
# 4
# 9
# 16
# 25
# 36

# %% [markdown]
# ### User-defined modules
#
# [Modules.](https://docs.python.org/3/tutorial/modules.html)
#
# [Best practices](https://docs.python.org/3/faq/programming.html#what-are-the-best-practices-for-using-import-in-a-module) for using import.
#
# Stand alone scripts:
# To create stand-alone scripts, must read: ```if __name__ == "__main__" ``` [stack_overflow](https://stackoverflow.com/questions/419163/what-does-if-name-main-do)
#
# Reloading and interactively working with modules.
# For efficiency reasons, each module is only imported once per interpreter session.
# Therefore, if you make changes in your modules, you must restart the interpreter – or, if want to test the module interactively, use importlib.reload(),
# e.g.
#
# ```import importlib;```
# ```importlib.reload(module_name)```

# %%
# the name of the main module is "__main__"
print(__name__)
# Out:
# __main__

# %%
# the name of the imported module is the explicit module name
import math
math.__name__
# Out:
# 'math'

# %%
# # the imported function also has a name.
math.sqrt.__name__
# Out:
# 'sqrt'

# %%
# not recommended method
from hypot_module import hypot_calculator_modular

# this function works without reference to module name
hypot_calculator_modular()

# %%
# Recommended import method
import hypot_module

# %%
hypot_module.__name__
# Out:
# 'hypot_module'

# %%
# this function works with reference to module name
hypot_module.hypot_calculator_modular()
# Out:
# Insert side a:  3
# Insert side b:  4
# Hypotenuse =  5.0

# %%
# Uncomment line that calls the function in the *.py file.
# Then run this cell.
import importlib

# reload() function reloads the module with the changes you made in it.
importlib.reload(hypot_module)

hypot_module.hypot_calculator_modular()
# Out:
# Insert side a:  4
# Insert side b:  5
# Hypotenuse =  6.4031242374328485
