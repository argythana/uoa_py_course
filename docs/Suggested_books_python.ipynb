# %% [markdown]
# # Suggested Books for the Python course
#
# - Automate the Boring Stuff with Python: Practical Programming, by Al Sweigart.
# - Python for Data Analysis, by Wes McKinney.
# - An Introduction to Machine Learning with Python, by Andreas C. Müller and Sarah Guido.
# - Hands-On Data Structures and Algorithms with Python: Store, manipulate, and access data effectively and boost the performance of your applications, 3rd Edition, by Dr. Basant Agarwal.
# - Designing Machine Learning Systems, Chip Huyen
#
# Thanasis Argyriou
