# %% [markdown]
# # Lecture 06a: Introduction to Pandas
#
# ## What is [pandas.](https://pandas.pydata.org/)
#
# [Pandas wikipedia entry:](https://en.wikipedia.org/wiki/Pandas_(software))
#
# **Necessary homework reading:**
# 1) From the [User Guide](https://pandas.pydata.org/docs/user_guide/index.html), study: [10 minutes to pandas](https://pandas.pydata.org/docs/user_guide/10min.html). As the title says, it takes no more than 2 hours and 10 minutes!
# 2) More on [indexing and selecting data:](https://pandas.pydata.org/docs/user_guide/indexing.html#)
#
# Advanced Reading: more complex recipes in the pandas [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook).
#
# ### Open a csv file.
# ### Basic info about a pandas dataframe.
# ### Indexing, slicing a pandas dataframe.
#
# ### Extra lecture Resources:
# [kaggle competition](https://www.kaggle.com/c/kaggle-survey-2020)
#
# [My team submission, at the kaggle competition](https://www.kaggle.com/pmav99/spam-identification-and-data-scientists-profile)
#
# [Github link with the notebook code for the kaggle competition](https://github.com/argythana/dsml_survey_20)

# %%
pwd  # Present working directory. This is where you norebook is running on your computer.
# Out:
# '/home/tharg/venv_projects/uoa_py_course/lectures_07_12_pandas_plots_scikit/lecture_07_pandas'

# %% [markdown]
# #### Module not found error if not installed.
# **To Install it, open CLI, go to course folder, activate venv, type`pip install pandas` .**

# %%
# Import module_name as alias (useful convention)
import pandas as pd

# %% [markdown]
# ## 1. Open a `.csv` file and read the data as a pandas dataframe.

# %% [markdown]
# #### If you get a very red, angry "FileNotFoundError" (file not found Error):
#
# Guess what is the problem:
# a) You don't have the file in the correct folder.
# b) You don't use the correct file name.
# c) YOu don't run the notebook from the correct folder.
#
# **d) Our teacher is sooo bad, and it is his fault!**
#
# e) All of the above.
#
# e) Is is the correct answer, if you are a beginner, and that's normal because it is mainly **d)**.

# %%
# First download the file from the eclass directory!

# Uncomment to use the code below if you put the data file in the same folder as the notebook.
# df = pd.read_csv("temp_to_coffee.csv")

# %%
# Use the code below if you put the data file in a directory that has the same structure as I do.
# If not, comment it out.
df = pd.read_csv("../../data/temp_to_coffee.csv")

# %%
# see the dataframe
df
# Out:
#      X    Y
# 0   20  396
# 1   22  297
# 2   23  397
# 3   18  425
# 4   19  425
# 5   24  260
# 6   25  250
# 7   20  299
# 8   22  520
# 9   18  498
# 10  16  434
# 11  16  285
# 12  17  496
# 13  20  360
# 14  21  417
# 15  19  409
# 16  15  493
# 17  15  509
# 18  18  406
# 19  20  410

# %%
# first 4 rows
df.head(4)
# Out:
#     X    Y
# 0  20  396
# 1  22  297
# 2  23  397
# 3  18  425

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 2. Basic dataframe methods, functions, attributes.

# %%
# number of rows.
len(df)
# Out:
# 20

# %%
# the names of the columns in the data
df.columns
# Out:
# Index(['X', 'Y'], dtype='object')

# %%
# number of observations in each column.
df.count()
# Out:
# X    20
# Y    20
# dtype: int64

# %%
# number of data points (rows * columns).
df.size
# Out:
# 40

# %%
# number of rows and columns.
df.shape
# Out:
# (20, 2)

# %%
df.shape[0]
# Out:
# 20

# %%
# number of columns.
df.shape[1]
# Out:
# 2

# %%
# index with the number of rows.
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df.describe()
# Out:
#                X           Y
# count  20.000000   20.000000
# mean   19.400000  399.300000
# std     2.872739   84.109014
# min    15.000000  250.000000
# 25%    17.750000  344.750000
# 50%    19.500000  409.500000
# 75%    21.250000  448.750000
# max    25.000000  520.000000

# %%
# percentiles takes a list as an argument
df.describe(percentiles=[0.1, 0.2, 0.4, 0.95])
# Out:
#                X           Y
# count  20.000000   20.000000
# mean   19.400000  399.300000
# std     2.872739   84.109014
# min    15.000000  250.000000
# 10%    15.900000  282.500000
# 20%    16.800000  298.600000
# 40%    18.600000  402.400000
# 50%    19.500000  409.500000
# 95%    24.050000  509.550000
# max    25.000000  520.000000

# %% [markdown]
# ### New dataframe
# Same name, df. Why? Convention, Reproducabilty, Readability, Presentation purposes.

# %%
# Uncomment the code below and press tab. 
#pd.read_


# Comment it out again.

# %%
# Uncomment the code below and run. 
# pd.read_csv?

# Comment it out again.
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'UsecolsArgType' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None,
# ...

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
df = pd.read_csv(
    "../../data/kaggle_survey_2020_responses.csv",
    # "kaggle_survey_2020_responses.csv",
    usecols=[0, 1, 2, 3, 4, 5, 6],
    low_memory=False,
)

# Use the code below if you put the data file in the same folder as the notebook.
# df = pd.read_csv(
#     "kaggle_survey_2020_responses.csv",  # Only change is the file name.
#     usecols=[0, 1, 2, 3, 4, 5, 6],
#     low_memory=False,
# )

# %%
# pandas dataframe
df
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                    1838                        35-39
# 2                                  289287                        30-34
# 3                                     860                        35-39
# 4                                     507                        30-34
# ...                                   ...                          ...
# 20032                                 126                        18-21
# 20033                                 566                        55-59
# 20034                                 238                        30-34
# 20035                                 625                        22-24
# 20036                                1031                        22-24
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# ...

# %%
# a random sample of 5 rows
df.sample(5)
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2  \
# 538                                   673  35-39    Man
# 10117                                 394  25-29  Woman
# 17027                                 753  40-44    Man
# 13568                                 408  22-24    Man
# 302                                  2613  35-39    Man
#
#                              Q3                 Q4                       Q5  \
# 538    United States of America  Bachelor’s degree  Product/Project Manager
# 10117                     India    Master’s degree                    Other
# 17027  United States of America  Bachelor’s degree        Software Engineer
# 13568                     India    Master’s degree                  Student
# 302                       Spain    Master’s degree            Data Engineer
#
#                 Q6
# 538      3-5 years
# 10117    1-2 years
# 17027  10-20 years
# 13568    3-5 years
# 302     5-10 years

# %%
df.columns
# Out:
# Index(['Time from Start to Finish (seconds)', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5',
#        'Q6'],
#       dtype='object')

# %%
# df.head(3)

# %%
# df.tail(3)

# %%
len(df)
# Out:
# 20037

# %%
# info on non-null and data types
df.info()  # Mind the decreasing number of non-null.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20037 entries, 0 to 20036
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Time from Start to Finish (seconds)  20037 non-null  object
#  1   Q1                                   20037 non-null  object
#  2   Q2                                   20037 non-null  object
#  3   Q3                                   20037 non-null  object
#  4   Q4                                   19570 non-null  object
#  5   Q5                                   19278 non-null  object
#  6   Q6                                   19121 non-null  object
# dtypes: object(7)
# memory usage: 1.1+ MB

# %% [markdown]
# ## 3. Columns and Index
# #### Columns: features, dimensions, variables (dependent, independent), X, y values (usually).

# %% [markdown]
# #### Integer Index = number or rows, observations, sample (usually).

# %%
# the index of the rows is a range of numbers, starting from 0.
df.index
# Out:
# RangeIndex(start=0, stop=20037, step=1)

# %%
# the data types
df.dtypes
# Out:
# Time from Start to Finish (seconds)    object
# Q1                                     object
# Q2                                     object
# Q3                                     object
# Q4                                     object
# Q5                                     object
# Q6                                     object
# dtype: object

# %% [markdown]
# ## 4. Select (Locate) based on index, or "labels", or "position".
# Recommended [answer](https://stackoverflow.com/a/31593712)
# Please pay attention to the examples understand the difference between `.loc` and `.iloc`.
# **Index for rows is first, then index for columns. (Rows, Columns).**

# %% [markdown]
# ### 4.1 Slice rows

# %%
# first row
df.iloc[0]
# Out:
# Time from Start to Finish (seconds)                                Duration (in seconds)
# Q1                                                           What is your age (# years)?
# Q2                                                What is your gender? - Selected Choice
# Q3                                             In which country do you currently reside?
# Q4                                     What is the highest level of formal education ...
# Q5                                     Select the title most similar to your current ...
# Q6                                     For how many years have you been writing code ...
# Name: 0, dtype: object

# %%
df.loc[0]  # same result different method. Be careful!
# Out:
# Time from Start to Finish (seconds)                                Duration (in seconds)
# Q1                                                           What is your age (# years)?
# Q2                                                What is your gender? - Selected Choice
# Q3                                             In which country do you currently reside?
# Q4                                     What is the highest level of formal education ...
# Q5                                     Select the title most similar to your current ...
# Q6                                     For how many years have you been writing code ...
# Name: 0, dtype: object

# %%
# second row
df.iloc[1]
# Out:
# Time from Start to Finish (seconds)               1838
# Q1                                               35-39
# Q2                                                 Man
# Q3                                            Colombia
# Q4                                     Doctoral degree
# Q5                                             Student
# Q6                                          5-10 years
# Name: 1, dtype: object

# %%
# iloc gets rows (and/or columns) at integer locations. Works on position.
# Works on index, works with numbers.
# iloc is exclusive.
df.iloc[0:2]  # exclusive of last index
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                1838                        35-39
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                   Colombia
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Doctoral degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                            Student
#
#                                                   Q6
# 0  For how many years have you been writing code ...
# 1                                         5-10 years

# %%
# .loc gets rows (and/or columns) with particular labels.
# .loc is label-based
#  (inclusive)
df.loc[0:2]
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                1838                        35-39
# 2                              289287                        30-34
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                   Colombia
# 2                   United States of America
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Doctoral degree
# 2                                    Master’s degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# ...

# %% [markdown]
# ### 4.2 Slice columns

# %%
# locate by name. Single brackets. This is a Series.
df["Q2"]
# Out:
# 0        What is your gender? - Selected Choice
# 1                                           Man
# 2                                           Man
# 3                                           Man
# 4                                           Man
#                           ...
# 20032                                       Man
# 20033                                     Woman
# 20034                                       Man
# 20035                                       Man
# 20036                                       Man
# Name: Q2, Length: 20037, dtype: object

# %%
type(df["Q2"])  # One bracket => Series.
# Out:
# pandas.core.series.Series

# %%
# Locate by name but use double brackets => This is a dataframe.
df[["Q2"]]
# Out:
#                                            Q2
# 0      What is your gender? - Selected Choice
# 1                                         Man
# 2                                         Man
# 3                                         Man
# 4                                         Man
# ...                                       ...
# 20032                                     Man
# 20033                                   Woman
# 20034                                     Man
# 20035                                     Man
# 20036                                     Man
#
# [20037 rows x 1 columns]

# %%
type(df[["Q2"]])  # two brackets => dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
# A list of [column names]
df[["Q2", "Q5", "Q3"]]
# Out:
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# 1                                         Man
# 2                                         Man
# 3                                         Man
# 4                                         Man
# ...                                       ...
# 20032                                     Man
# 20033                                   Woman
# 20034                                     Man
# 20035                                     Man
# 20036                                     Man
#
#                                                       Q5  \
# 0      Select the title most similar to your current ...
# 1                                                Student
# 2                                          Data Engineer
# 3                                      Software Engineer
# 4                                         Data Scientist
# ...                                                  ...
# ...

# %% [markdown]
# ### 4.3 Slice rows and columns

# %%
# Locate a range of names for the rows and a range of names for the columns.
# All rows, and only columns with names from 'Q2' to 'Q5'
df.loc[0:5, 'Q2':'Q4']
# Out:
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
# 5                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                   Colombia
# 2                   United States of America
# 3                                  Argentina
# 4                   United States of America
# 5                                      Japan
#
#                                                   Q4
# 0  What is the highest level of formal education ...
# 1                                    Doctoral degree
# 2                                    Master’s degree
# 3                                  Bachelor’s degree
# 4                                    Master’s degree
# ...

# %%
# Locate a range of names for the rows and a range of names for the columns.
df.loc[:, 'Q2':'Q4']
# Out:
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# 1                                         Man
# 2                                         Man
# 3                                         Man
# 4                                         Man
# ...                                       ...
# 20032                                     Man
# 20033                                   Woman
# 20034                                     Man
# 20035                                     Man
# 20036                                     Man
#
#                                                       Q3  \
# 0              In which country do you currently reside?
# 1                                               Colombia
# 2                               United States of America
# 3                                              Argentina
# 4                               United States of America
# ...                                                  ...
# ...

# %%
# Locate a range of names for the rows and a range of names for the columns.
df.loc[:5, 'Q3':'Q5']
# Out:
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                   Colombia
# 2                   United States of America
# 3                                  Argentina
# 4                   United States of America
# 5                                      Japan
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Doctoral degree
# 2                                    Master’s degree
# 3                                  Bachelor’s degree
# 4                                    Master’s degree
# 5                                    Master’s degree
#
#                                                   Q5
# 0  Select the title most similar to your current ...
# 1                                            Student
# 2                                      Data Engineer
# 3                                  Software Engineer
# ...

# %%
type(df.loc[:, 'Q2':'Q3'])
# Out:
# pandas.core.frame.DataFrame

# %%
# .loc is inclusive, because it works with "names".
# Locate a range of names for the rows and a range of names for the columns.
df.loc[0:3, 'Q2':'Q4']    

# Inclusive, I repeat this many times, in case you missed it.
# Out:
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                   Colombia
# 2                   United States of America
# 3                                  Argentina
#
#                                                   Q4
# 0  What is the highest level of formal education ...
# 1                                    Doctoral degree
# 2                                    Master’s degree
# 3                                  Bachelor’s degree

# %%
# Locate a range of names for the rows and a range of names for the columns.
# First 11 rows, all columns.
df.loc[0:10, :]
# Out:
#    Time from Start to Finish (seconds)                           Q1  \
# 0                Duration (in seconds)  What is your age (# years)?
# 1                                 1838                        35-39
# 2                               289287                        30-34
# 3                                  860                        35-39
# 4                                  507                        30-34
# 5                                   78                        30-34
# 6                                  401                        30-34
# 7                                  748                        22-24
# 8                               171196                        25-29
# 9                                  762                        35-39
# 10                                 150                        22-24
#
#                                         Q2  \
# 0   What is your gender? - Selected Choice
# 1                                      Man
# ...

# %%
# Locate a range of names for the rows and a list of names for the columns.
df.loc[0:6, ['Q2', 'Q5']]
# Out:
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
# 5                                     Man
# 6                                     Man
#
#                                                   Q5
# 0  Select the title most similar to your current ...
# 1                                            Student
# 2                                      Data Engineer
# 3                                  Software Engineer
# 4                                     Data Scientist
# 5                                  Software Engineer
# 6                                       Data Analyst

# %%
# Locate a names of a row and a name of a column.
# value of a single "value" in a row.

df.loc[8, 'Q2']
# Out:
# 'Woman'

# %% [markdown]
# ## 5. Alternative syntax to slice rows and columns.
# You may use similar notation to lists and strings indexing, without `.loc` nor `iloc` .

# %%
# value of a single "value" in a row.
df.Q2[8]
# Out:
# 'Woman'

# %%
# Basic indexing as we do it in lists and strings works similarly on df rows.
# EXCLUSIVE because it works with ordered indexing in numbers.

df[10:13]
# Out:
#    Time from Start to Finish (seconds)     Q1   Q2                        Q3  \
# 10                                 150  22-24  Man                     China
# 11                                7469  18-21  Man                     India
# 12                                 742  35-39  Man  United States of America
#
#                                       Q4                  Q5         Q6
# 10  No formal education past high school             Student  < 1 years
# 11                     Bachelor’s degree             Student  1-2 years
# 12                       Doctoral degree  Research Scientist  1-2 years

# %%
# Basic indexing as we do it in lists and strings works similarly on df columns.
# EXCLUSIVE because it works with ordered indexing in number.
df.Q2[10:13]
# Out:
# 10    Man
# 11    Man
# 12    Man
# Name: Q2, dtype: object

# %%
# Basic indexing as we do it in lists and strings works similarly on df columns.
# Same result as above, different syntax.
# EXCLUSIVE because it works with ordered indexing in numbers.

df["Q2"][10:13]
# Out:
# 10    Man
# 11    Man
# 12    Man
# Name: Q2, dtype: object

# %%
df[10:13]["Q2"]
# Out:
# 10    Man
# 11    Man
# 12    Man
# Name: Q2, dtype: object

# %%
# Basic indexing as we do it in lists and strings works similarly on df columns and rows.
# Same result as above, different syntax.
df[["Q1", "Q2"]][10:13]
# Out:
#        Q1   Q2
# 10  22-24  Man
# 11  18-21  Man
# 12  35-39  Man

# %%
# Basic indexing as we do it in lists and strings works similarly on df columns and rows.
# Same result as above, different syntax.
df[10:13][["Q1", "Q2"]]
# Out:
#        Q1   Q2
# 10  22-24  Man
# 11  18-21  Man
# 12  35-39  Man

# %%
# Five values of column Q6, before the last five values. Sorry for this example.
df.Q6[-10:-5]
# Out:
# 20027      3-5 years
# 20028      3-5 years
# 20029      < 1 years
# 20030    10-20 years
# 20031            NaN
# Name: Q6, dtype: object

# %%
type(df.Q6[-10:-5])
# Out:
# pandas.core.series.Series

# %%
# Expert slcicing pandas example to burn your brains cells. 
# Really very sorry for this one.
# Slice rows and then slice rows again.
# Again, I feel the need to apologize.

df[5:10][0:3]
# Out:
#   Time from Start to Finish (seconds)     Q1   Q2      Q3                 Q4  \
# 5                                  78  30-34  Man   Japan    Master’s degree
# 6                                 401  30-34  Man   India  Bachelor’s degree
# 7                                 748  22-24  Man  Brazil  Bachelor’s degree
#
#                   Q5         Q6
# 5  Software Engineer  3-5 years
# 6       Data Analyst  < 1 years
# 7            Student  3-5 years

# %%
# df[0:5][0:3] 
# Produce the same result, step by step,  in the two code cells below:
slice_on_df_rows = df[5:10]  # Rows with index number from 5 to 9
# first_slice_on_all_df_rows

# %%
slice_on_df_rows
# Out:
#   Time from Start to Finish (seconds)     Q1     Q2       Q3  \
# 5                                  78  30-34    Man    Japan
# 6                                 401  30-34    Man    India
# 7                                 748  22-24    Man   Brazil
# 8                              171196  25-29  Woman    China
# 9                                 762  35-39    Man  Germany
#
#                   Q4                 Q5          Q6
# 5    Master’s degree  Software Engineer   3-5 years
# 6  Bachelor’s degree       Data Analyst   < 1 years
# 7  Bachelor’s degree            Student   3-5 years
# 8    Master’s degree            Student   < 1 years
# 9    Doctoral degree     Data Scientist  5-10 years

# %%
second_slice = slice_on_df_rows[0:3]  # (Rows 1 until 3) from (rows 5 to 9)
second_slice

# REALY SORRY FOR THIS, but if you get it, it will save you hundreds of hours in the future.
# Out:
#   Time from Start to Finish (seconds)     Q1   Q2      Q3                 Q4  \
# 5                                  78  30-34  Man   Japan    Master’s degree
# 6                                 401  30-34  Man   India  Bachelor’s degree
# 7                                 748  22-24  Man  Brazil  Bachelor’s degree
#
#                   Q5         Q6
# 5  Software Engineer  3-5 years
# 6       Data Analyst  < 1 years
# 7            Student  3-5 years

# %% [markdown]
# ### Can you spot the difference in the two alternative syntaxes?

# %%
df.loc[:5, 'Q2']
# Out:
# 0    What is your gender? - Selected Choice
# 1                                       Man
# 2                                       Man
# 3                                       Man
# 4                                       Man
# 5                                       Man
# Name: Q2, dtype: object

# %%
df.Q2[:5]
# Out:
# 0    What is your gender? - Selected Choice
# 1                                       Man
# 2                                       Man
# 3                                       Man
# 4                                       Man
# Name: Q2, dtype: object

# %%
df[2:5]["Q1"]
# Out:
# 2    30-34
# 3    35-39
# 4    30-34
# Name: Q1, dtype: object

# %% [markdown]
# ## 6. Transpose a df.
# Sometimes it is needed.
# Here I use it to explain `.loc` and `.iloc` and to demonstrate row indices that have worded labels instead of numbers.

# %%
# Nothing but a view.
df.transpose().head(4)  # alternative syntax: df.T
# Out:
#                                                                          0      \
# Time from Start to Finish (seconds)                      Duration (in seconds)
# Q1                                                 What is your age (# years)?
# Q2                                      What is your gender? - Selected Choice
# Q3                                   In which country do you currently reside?
#
#                                         1                         2      \
# Time from Start to Finish (seconds)      1838                    289287
# Q1                                      35-39                     30-34
# Q2                                        Man                       Man
# Q3                                   Colombia  United States of America
#
#                                          3                         4      \
# Time from Start to Finish (seconds)        860                       507
# ...

# %%
# df has not changed in memory. This is a view of the df.
df
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                    1838                        35-39
# 2                                  289287                        30-34
# 3                                     860                        35-39
# 4                                     507                        30-34
# ...                                   ...                          ...
# 20032                                 126                        18-21
# 20033                                 566                        55-59
# 20034                                 238                        30-34
# 20035                                 625                        22-24
# 20036                                1031                        22-24
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# ...

# %%
# Nothing but a view of the transpose of the df.
df.T
# Out:
#                                                                                  0      \
# Time from Start to Finish (seconds)                              Duration (in seconds)
# Q1                                                         What is your age (# years)?
# Q2                                              What is your gender? - Selected Choice
# Q3                                           In which country do you currently reside?
# Q4                                   What is the highest level of formal education ...
# Q5                                   Select the title most similar to your current ...
# Q6                                   For how many years have you been writing code ...
#
#                                                1      \
# Time from Start to Finish (seconds)             1838
# Q1                                             35-39
# Q2                                               Man
# Q3                                          Colombia
# ...

# %%
# df has not changed in memory.
df
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                    1838                        35-39
# 2                                  289287                        30-34
# 3                                     860                        35-39
# 4                                     507                        30-34
# ...                                   ...                          ...
# 20032                                 126                        18-21
# 20033                                 566                        55-59
# 20034                                 238                        30-34
# 20035                                 625                        22-24
# 20036                                1031                        22-24
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# ...

# %%
# Store a new name in memory and keep df as it is.
transposed_df = df.T  # T is an alias for the transpose() function

# %%
transposed_df
# Out:
#                                                                                  0      \
# Time from Start to Finish (seconds)                              Duration (in seconds)
# Q1                                                         What is your age (# years)?
# Q2                                              What is your gender? - Selected Choice
# Q3                                           In which country do you currently reside?
# Q4                                   What is the highest level of formal education ...
# Q5                                   Select the title most similar to your current ...
# Q6                                   For how many years have you been writing code ...
#
#                                                1      \
# Time from Start to Finish (seconds)             1838
# Q1                                             35-39
# Q2                                               Man
# Q3                                          Colombia
# ...

# %%
# this works, using numerical index
transposed_df.iloc[0:4]
# Out:
#                                                                          0      \
# Time from Start to Finish (seconds)                      Duration (in seconds)
# Q1                                                 What is your age (# years)?
# Q2                                      What is your gender? - Selected Choice
# Q3                                   In which country do you currently reside?
#
#                                         1                         2      \
# Time from Start to Finish (seconds)      1838                    289287
# Q1                                      35-39                     30-34
# Q2                                        Man                       Man
# Q3                                   Colombia  United States of America
#
#                                          3                         4      \
# Time from Start to Finish (seconds)        860                       507
# ...

# %%
# This does work with names of rows, using the names.
transposed_df.loc["Q1": "Q2"]
# Out:
#                                      0      1      2      3      4      5      \
# Q1             What is your age (# years)?  35-39  30-34  35-39  30-34  30-34
# Q2  What is your gender? - Selected Choice    Man    Man    Man    Man    Man
#
#     6      7      8      9      ...  20027  20028  20029  20030  20031  20032  \
# Q1  30-34  22-24  25-29  35-39  ...  22-24  25-29  30-34  35-39  18-21  18-21
# Q2    Man    Man  Woman    Man  ...  Woman    Man    Man    Man    Man    Man
#
#     20033  20034  20035  20036
# Q1  55-59  30-34  22-24  22-24
# Q2  Woman    Man    Man    Man
#
# [2 rows x 20037 columns]

# %%
# using ranges of [names of rows, names of columns]
transposed_df.loc["Q1": "Q4", 1:6]
# Out:
#                   1                         2                  3  \
# Q1            35-39                     30-34              35-39
# Q2              Man                       Man                Man
# Q3         Colombia  United States of America          Argentina
# Q4  Doctoral degree           Master’s degree  Bachelor’s degree
#
#                            4                5                  6
# Q1                     30-34            30-34              30-34
# Q2                       Man              Man                Man
# Q3  United States of America            Japan              India
# Q4           Master’s degree  Master’s degree  Bachelor’s degree

# %%
transposed_df.index
# Out:
# Index(['Time from Start to Finish (seconds)', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5',
#        'Q6'],
#       dtype='object')

# %%
# the rows are the columns of the transposed df
transposed_df.columns
# Out:
# RangeIndex(start=0, stop=20037, step=1)

# %%
# first row using the name of the row.
transposed_df.loc["Q1"]
# Out:
# 0        What is your age (# years)?
# 1                              35-39
# 2                              30-34
# 3                              35-39
# 4                              30-34
#                     ...
# 20032                          18-21
# 20033                          55-59
# 20034                          30-34
# 20035                          22-24
# 20036                          22-24
# Name: Q1, Length: 20037, dtype: object

# %%
# this works using a range of [names of rows]
transposed_df.loc["Q1": "Q4"]
# Out:
#                                                 0                1      \
# Q1                        What is your age (# years)?            35-39
# Q2             What is your gender? - Selected Choice              Man
# Q3          In which country do you currently reside?         Colombia
# Q4  What is the highest level of formal education ...  Doctoral degree
#
#                        2                  3                         4      \
# Q1                     30-34              35-39                     30-34
# Q2                       Man                Man                       Man
# Q3  United States of America          Argentina  United States of America
# Q4           Master’s degree  Bachelor’s degree           Master’s degree
#
#               5                  6                  7                8      \
# Q1            30-34              30-34              22-24            25-29
# Q2              Man                Man                Man            Woman
# ...

# %%
# this works # using selected names of rows
transposed_df.loc[["Q1", "Q4", "Q6"]]
# Out:
#                                                 0                1      \
# Q1                        What is your age (# years)?            35-39
# Q4  What is the highest level of formal education ...  Doctoral degree
# Q6  For how many years have you been writing code ...       5-10 years
#
#               2                  3                4                5      \
# Q1            30-34              35-39            30-34            30-34
# Q4  Master’s degree  Bachelor’s degree  Master’s degree  Master’s degree
# Q6       5-10 years        10-20 years       5-10 years        3-5 years
#
#                 6                  7                8                9      \
# Q1              30-34              22-24            25-29            35-39
# Q4  Bachelor’s degree  Bachelor’s degree  Master’s degree  Doctoral degree
# Q6          < 1 years          3-5 years        < 1 years       5-10 years
#
#     ...            20027            20028            20029              20030  \
# ...

# %% [markdown]
# #### Revision example

# %%
# This does not work. Do you understand why?
# No We don't!
# +500 points if you find it.

transposed_df.loc["Q1", "Q4"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[157], line 6
#       1 # This does not work. Do you understand why?
#       2 # No We don't!
#       3 # +500 points if you find it.
# ----> 6 transposed_df.loc["Q1", "Q2"]
#
# File ~/venv_projects/uoa_py_course/course_venv/lib/python3.11/site-packages/pandas/core/indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File ~/venv_projects/uoa_py_course/course_venv/lib/python3.11/site-packages/pandas/core/frame.py:4202, in DataFrame._get_value(self, index, col, takeable)
# ...

# %%
# Solution: double brackets. There is no index named ("Q1", "Q2").
# With a single bracket it is read as a single row name "Q1", not as list of row names.
# Then, after the comma, pandas looks for a column with name "Q2" but there is no such column in the transposed df.

# %%
# Locates a [list of names] of rows.
transposed_df.loc[["Q1", "Q4"]]
# Out:
#                                                 0                1      \
# Q1                        What is your age (# years)?            35-39
# Q4  What is the highest level of formal education ...  Doctoral degree
#
#               2                  3                4                5      \
# Q1            30-34              35-39            30-34            30-34
# Q4  Master’s degree  Bachelor’s degree  Master’s degree  Master’s degree
#
#                 6                  7                8                9      \
# Q1              30-34              22-24            25-29            35-39
# Q4  Bachelor’s degree  Bachelor’s degree  Master’s degree  Doctoral degree
#
#     ...            20027            20028            20029              20030  \
# Q1  ...            22-24            25-29            30-34              35-39
# Q4  ...  Master’s degree  Master’s degree  Master’s degree  Bachelor’s degree
#
# ...

# %%
# locate the name for row "Q1" and then, after the comma, locate the name of the column 2.
transposed_df.loc["Q1", 2]
# Out:
# '30-34'

# %% [markdown]
# #### Summary: a list of names for columns or rows needs the proper syntax.

# %%
# Locates a [list of names] of rows and a [list of names] for the columns.
transposed_df.loc[["Q1", "Q5"], [2, 3, 4, 5]]
# Out:
#                 2                  3               4                  5
# Q1          30-34              35-39           30-34              30-34
# Q5  Data Engineer  Software Engineer  Data Scientist  Software Engineer

# %%
# Slice a range of names OF  rows and a range of names OF THE ROWS AGAIN.
# COLUMNS are not sliced with this syntax. Be very careful.
# SORRY, hope you don't hate me after this example.

transposed_df[:"Q5"][3:6]
# Out:
#                                                 0                1      \
# Q3          In which country do you currently reside?         Colombia
# Q4  What is the highest level of formal education ...  Doctoral degree
# Q5  Select the title most similar to your current ...          Student
#
#                        2                  3                         4      \
# Q3  United States of America          Argentina  United States of America
# Q4           Master’s degree  Bachelor’s degree           Master’s degree
# Q5             Data Engineer  Software Engineer            Data Scientist
#
#                 5                  6                  7                8      \
# Q3              Japan              India             Brazil            China
# Q4    Master’s degree  Bachelor’s degree  Bachelor’s degree  Master’s degree
# Q5  Software Engineer       Data Analyst            Student          Student
#
#               9      ...                   20027            20028  \
# ...
